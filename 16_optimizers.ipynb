# %% [markdown]
# <a href="https://colab.research.google.com/github/TanujaMore27/Deep-Learning/blob/main/16_optimizers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Optimizers in Deep Learning :
#
# ####Role of Optimizer :
# * neural network is actually an optimization problem where it tries to minimize the loss.in this process the weight and biases optimized values makes the neural network optimized.
# * in deep learning we use optimizer as Gradient Descent
#
# #### Types of Optimizers :
# 1.Batch GD
# 2.Stochastic GD
# 3. Mini-Batch GD
#
# #### Challenges :
# 1.learning rate --> if too high or too low can result into not reaching the minima.
#
# 2.Learning rate Scheduling --> have to predefine before training but same will not work for all datasets.
#
# 3.if we have 2 weights then we cannot give different learning rates to both we have to give them all same.it is the restriction that is in both direction you will reach the minima by same steps in both direction.
#
# 4.local minima , best solution is global minima but there is too much possibility that we will be in local minima(sometimes solve by stochastic gradient by his zigzag motion.) so sometimes we have to be with sub optimal solution.
#
# 5.Saddle Point : slope of one dimension goes down and of other dimension goes up.resulting in slope remains same for the all direction so the differentiation becomes zero results in no change in weight update even its not the optimal solution.

# %% [markdown]
# ### Exponentially Weighted Moving Average or Exponential Weighted Average :

# %% [markdown]
# ![Screenshot 2026-04-07 104520.png](data:image/png;base64,...)

# %% [markdown]
# * it is used to find trends and patterns from time series based data.
# * it is used in time series forcasting,financial forecasting ,signal processing , deep learning while building some cool optimizers.
#
# *** 1.while using EWMA we value further(new) points rather than previous(old) ones
# *** 2.current points has high weightage and as we move further previous points weightage decreases.
# *** EWMV is a technique used to find out hidden trends in time series based data.

# %% [markdown]
# * if beta=0.9 then 1/1-beta = 10 so the average at that point  behaves like the normal average of before 10 days.
# * higher the beta values giving high weightage to the previous points and vice-versa so that at low value of beta the graph becomes spiky.
# * so we look for the sweet spot which is generally beta = 0.9

# %% [markdown]
# ![Screenshot 2026-04-25 091326.png](data:image/png;base64,...)

# %% [markdown]
# #### Mathematical Intution :
# ![Screenshot 2026-04-07 105751.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-07 105918.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-07 110851.png](data:image/png;base64,...)

# %% [markdown]
# # optimizers :
#
# ### SGD with Momentum :
# ![Screenshot 2026-04-07 120944.png](data:image/png;base64,...)

# %% [markdown]
# *** Convex VS Non-Convex Optimization :
#
# ![Screenshot 2026-04-07 121519.png](data:image/png;base64,...)

# %% [markdown]
# * we have to traverse to the minima of the curve . if we are in non-convex curve optimization problem then its becomes difficult to go to the minima due to three main problems :
#
# 1.Local Minima
# 2.Saddle Point(ek direction mein uth raha hai dusare mein baith raha hai curve)
# 3.High Curvature :
#
# ![Screenshot 2026-04-07 122025.png](data:image/png;base64,...)
#
# * small radius high curvature and vice-versa
# * difficult to traverse this curvature.
#
# these problems are not navigated by gradient descent so out results are not optimal or they are sub-optimal or slow training.

# %% [markdown]
# ### Convex Vs Non-convex Cost Function:
# * (Difference between convex & non-convex cost function; what happens when cost function is non-convex?)
# * in mathematics, a real values function is called convex if the line segment between any two pints on the graph of the function does not lie below the graph between two pints.
#
# ![image.png](data:image/png;base64,...)
#
# * convex function plays an important role in many areas of mathematics.They are especially important in the study of optimization problems where they are distinguished by the number of convenient properties.for instance, a stricklyconvex function on an open set has no more than one minima.
# * in optimization problem we try to find best answer by global minima but if it is non-convex problem then there is possibility of getting local minima solution.
# * for strickly non-convex function there will be more than one minima.

# %% [markdown]
# #### Momentum Optimization - The Why ? :
# * momentum solves following problems --
#
# ![Screenshot 2026-04-07 123204.png](data:image/png;base64,...)
#
# ![Screenshot 2026-04-07 123447.png](data:image/png;base64,...)

# %% [markdown]
# #### Core Principle :
# * The advantage of using momentum optimization is SPEED.
# * because if our previous gradients are together saying to move towards same direction then it moves confidently in that direction and if some are saying different they we go slow , so same direction guide by all gradient results into fast speed for training.
#
#
# #### How to implement the concept Mathematically :
#
# ![Screenshot 2026-04-07 124037.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-07 124256.png](data:image/png;base64,...)
#
#
# #### Effect of BETA :
#
# ![Screenshot 2026-04-07 124439.png](data:image/png;base64,...)
#
# * older the velocity has lower its impact and vice-versa
# * if BETA = 1 then there will be no decay the point will move on the surface smoothly from one end to other again and again(to and fro motion) as there is no friction involved results in dynamic equilibrium which is not desired.
#
# *** Advantages :
# * Accelerate the training
# * escape the local minima
#
# *** Here sometimes it biggest advantage becomes the disadvantage because its fastest than gradient descent but takes time or becomes slow  and oscillates at the global minima because it has momentum(slow means take time due to to and fro oscillations and slow the training). due to this momentum does not become fastest optimization technique.
# *** so the problem with it is MOMENTUM.

# %% [markdown]
# ### Nesterov Accelerated Gradient (NAG) :
#
# * It is an implementation of momentum but with improvement that is we reduce the number of oscillations
#
# **** Mathematical Intuition :
#
# ![Screenshot 2026-04-08 080442.png](data:image/png;base64,...)
#
# * in momentum the next point to jump is depend on both history of velocity + gradient at that point.
# *  while in NAG , first we calculate history of velocity(look ahead term) and go according to that point and on that point we calculate the gradient.
#
# *** Geometric Intuition :
#
# ![Screenshot 2026-04-08 081030.png](data:image/png;base64,...)
#
#
# *** Disadvantages :
# - can ended up in local minima - because in momentum it was taking too much oscillations and momentum it can climb up from local minima but in NAG due to less oscillation and it may be have less momentum it is possible that it will not climb through local minima.
#
# -----Keras code :
#
# ![Screenshot 2026-04-08 081448.png](data:image/png;base64,...)

# %% [markdown]
# ### AdaGrad (Adaptive Gradient) :
# * in this optimizer learning rate is not fixed, its adapted(change) according to the situation.
# * if input features has different scales then this algorithm works better(but if it normalized then it is not useful)
# * if features are sparse(most of the values are 0) then we can use this algorithm.
# *** if data is sparse then its graph(contour plot) will be elongated(slope change at one axis and constant at other) at one dimension otherwise it will be some circular.
# * such problems i.e slope change at one axis and constant at other is not abled to solved by BGD , momentum , NAG but by ADAGRAD.
#
#
# **** What are the problems with these above algorit hms  :
# - when using gradient such as Batch and momentum there is no more movement in the direction of there dimension compare to B because it contains sparse values so it does not work properly with sparse values
# - when there is sparse col then weight update in that direction is small while in non-sparse weight update is normal or big.
#
# *** Mathematical Intuition :
#
# ![Screenshot 2026-04-08 120018.png](data:image/png;base64,...)
#
#
# * if the parameter gradent to update is big then we make the learning rate of it small and vice-versa.
#
# ![Screenshot 2026-04-08 120638.png](data:image/png;base64,...)
#
#
# * (epsolon is the very small term only for when vt becomes zero term should not reach to the infinity.) where vt stores the past gradients sum(squares),square not mode because its gradient will become zero.
# *** Disadvantages :
# - it goes close to the solution but cannot converge to it even if maximum epochs are given,
# the term we divide with learning rate becomes so high that it make learning rate too small making too small update,so we never reach the global minima.
# *so we dont use it in complex neural network but can be used in linear regression problems.
# *** we learn this because this theory will be used in further below algorithms.

# %% [markdown]
# ### RMSProp (Root Mean Square Propagation) :
# * it is an improvement over adagrad.
#
# #### Mathematical Formulation :
#
# ![Screenshot 2026-04-08 121216.png](data:image/png;base64,...)
#
#
# * we have to do something in adagrad inorder so that vt which was being big due to adding squares of all past gradient making the all term very small,so we have to stop vt to become big by using this algorithm.
# * this is done by making vt formula with exponential decaying average instead of adding squares of past terms,giving lessimportance to the older terms
# * the vt is calculated using above formula
#
# *** Disadvantages :
# - there is no disadvantage it works best so its best optimization technique. just ADAM is new which is somewhat better than it.

# %% [markdown]
# ### Adam Optimizer(Adaptive Moment Estimation) :
# * most popular algorithm used in RNN,ANN,CNN
# * adam takes base of all 5 above techniques.
#
# (merge)
#
# ![image.png](data:image/png;base64,...)
#
# *** Mathematical Formulation :
# ![Screenshot 2026-04-11 090646.png](data:image/png;base64,...)

# %% [markdown]
# ## ***  VERDICT :
# START WE ADAM IF NOT GET RESULTS TRY RMSPROP AND THEN HYPERPARAMETER TUNING.
