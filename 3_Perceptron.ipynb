# %% [markdown]
# <a href="https://colab.research.google.com/github/TanujaMore27/Deep-Learning/blob/main/3_Perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Perceptron :
# * It is an algorithm used in supervised learning.
# * It is designed such that it became the building block of the DL.
#
# Perceptron looks like this -
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Perceptron v/s Neuron :
# * Perceptron is weakly inspired by human neuron .
# * differences :
#   * complexity
#   * Processing
#   * Neuroplasticity(dendrites becomes thick thin according to strong or weak connection)

# %% [markdown]
# #### Interpretation :
# * weight in perceptrons tells about the strength of connection i.e tell feature importance.
# * as outputs are already given in training algo finds weights and bias according to the output and draws a line separating the region and according to that line makes predictions.
#
# #### Geometric Intution :
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * so in perceptron if two inputs are there it becomes equation of line separating two regions , in 3D it becomes plane and in 4D it becomes hyperplane .
#
# #### Limitation :
# * as perceptron separates classes by making regions it is only  applicable on linear or sort of linear data.
