# %% [markdown]
# <a href="https://colab.research.google.com/github/TanujaMore27/Deep-Learning/blob/main/5_MLP_notation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Multi-Perceptron Notations :
#
# * while looking at the architecture of neural network we should able to find training parameters i.e how much weights and biases have to calculate.
#
# ![image.png](data:image/png;base64,...)
#
# * for weights w we multiply first layer nodes and sencong layer nodes while for bias we take second layers number of node and so on and add them all weights and biases of all then thses are number of training parameters.

# %% [markdown]
# ### Notations :
# #### For Bias : b(subscript)(i,j)
# * i denotes layer number and j denoted node number.
#
# #### for ouput : same as bias
#
# #### for weights : i,j,k
#
# * k superscript which layer its going(apne se kis layer mein ghus raha hai)
# * i subscript which node it came from
# * j subscript to which node its going

# %% [markdown]
# ![image.png](data:image/png;base64,...)
